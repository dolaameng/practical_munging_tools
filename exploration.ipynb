# %%
# %load_ext autoreload
# %autoreload 2

from munging import imputation
from munging import inspection
from munging import utility
from munging import transformation
from munging import feature


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
custdata = pd.read_table("data/custdata.tsv")

# %%
custdata.head()
# Out:
#    custid sex is.employed  income   marital.stat health.ins  \
# 0    2068   F         NaN   11300        Married       True
# 1    2073   F         NaN       0        Married       True
# 2    2848   M        True    4500  Never Married      False
# 3    5641   M        True   20000  Never Married      False
# 4    6369   F        True   12000  Never Married       True
#
#                housing.type recent.move  num.vehicles  age state.of.res
# 0  Homeowner free and clear       False             2   49     Michigan
# 1                    Rented        True             3   40      Florida
# 2                    Rented        True             3   22      Georgia
# 3     Occupied with no rent       False             0   22   New Mexico
# 4                    Rented        True             1   31      Florida

# %% [markdown]
# ## Missing Values

# %%
inspection.na_pattern(custdata)
# Out:
# munging/inspection.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   na_patterns["occurrence"] = occurrences
#   custid sex is.employed income marital.stat health.ins housing.type  \
# 0      -   -     missing      -            -          -            -
# 1      -   -           -      -            -          -            -
# 2      -   -           -      -            -          -      missing
# 3      -   -     missing      -            -          -      missing
# 4      0   0         328      0            0          0           56
#
#   recent.move num.vehicles age state.of.res  occurrence
# 0           -            -   -            -         280
# 1           -            -   -            -         664
# 2     missing      missing   -            -           8
# 3     missing      missing   -            -          48
# 4          56           56   0            0        1000

# %%
categorical_features = inspection.find_categorical_features(custdata)
print categorical_features
# Out:
# ['sex' 'is.employed' 'marital.stat' 'health.ins' 'housing.type'
#  'recent.move' 'state.of.res']

# %%
df = imputation.imput_categorical_features(custdata, categorical_features)

# %%
inspection.na_pattern(df)
# Out:
#   custid sex is.employed income marital.stat health.ins housing.type  \
# 0      -   -           -      -            -          -            -
# 1      -   -           -      -            -          -            -
# 2      0   0           0      0            0          0            0
#
#   recent.move num.vehicles age state.of.res  occurrence
# 0           -            -   -            -         944
# 1           -      missing   -            -          56
# 2           0           56   0            0        1000

# %%
for f in categorical_features:
    print pd.unique(df[f])
# Out:
# ['F' 'M']
# ['missing' True False]
# ['Married' 'Never Married' 'Divorced/Separated' 'Widowed']
# [True False]
# ['Homeowner free and clear' 'Rented' 'Occupied with no rent'
#  'Homeowner with mortgage/loan' 'missing']
# [False True 'missing']
# ['Michigan' 'Florida' 'Georgia' 'New Mexico' 'New York' 'Idaho' 'Illinois'
#  'North Carolina' 'Indiana' 'New Hampshire' 'South Carolina' 'Pennsylvania'
#  'Virginia' 'New Jersey' 'Ohio' 'Missouri' 'California' 'Wisconsin'
#  'South Dakota' 'Colorado' 'Oklahoma' 'Kentucky' 'Massachusetts' 'Texas'
#  'Maryland' 'Connecticut' 'Mississippi' 'Arkansas' 'Washington'
#  'Rhode Island' 'Minnesota' 'Alaska' 'Tennessee' 'Iowa' 'Kansas' 'Oregon'
#  'Alabama' 'Arizona' 'West Virginia' 'Louisiana' 'Vermont' 'Maine' 'Hawaii'
#  'Utah' 'Wyoming' 'Nebraska' 'Nevada' 'Delaware' 'Montana' 'North Dakota']

# %%
numerical_features = inspection.find_numerical_features(custdata)
print numerical_features
df = imputation.imput_numerical_features(custdata, numerical_features, )
# Out:
# ['custid' 'income' 'num.vehicles' 'age']

# %%
inspection.na_pattern(df)
# Out:
#   custid sex is.employed income marital.stat health.ins housing.type  \
# 0      -   -     missing      -            -          -            -
# 1      -   -           -      -            -          -            -
# 2      -   -           -      -            -          -      missing
# 3      -   -     missing      -            -          -      missing
# 4      0   0         328      0            0          0           56
#
#   recent.move num.vehicles age state.of.res num.vehicles_isna  occurrence
# 0           -            -   -            -                 -         280
# 1           -            -   -            -                 -         664
# 2     missing            -   -            -                 -           8
# 3     missing            -   -            -                 -          48
# 4          56            0   0            0                 0        1000

# %%
df = imputation.imput(custdata)
inspection.na_pattern(df)
# Out:
#   custid sex is.employed income marital.stat health.ins housing.type  \
# 0      -   -           -      -            -          -            -
# 1      0   0           0      0            0          0            0
#
#   recent.move num.vehicles age state.of.res num.vehicles_isna  occurrence
# 0           -            -   -            -                 -        1000
# 1           0            0   0            0                 0        1000

# %%
df.head()
# Out:
#    custid sex is.employed  income   marital.stat health.ins  \
# 0    2068   F     missing   11300        Married       True
# 1    2073   F     missing       0        Married       True
# 2    2848   M        True    4500  Never Married      False
# 3    5641   M        True   20000  Never Married      False
# 4    6369   F        True   12000  Never Married       True
#
#                housing.type recent.move  num.vehicles  age state.of.res  \
# 0  Homeowner free and clear       False             2   49     Michigan
# 1                    Rented        True             3   40      Florida
# 2                    Rented        True             3   22      Georgia
# 3     Occupied with no rent       False             0   22   New Mexico
# 4                    Rented        True             1   31      Florida
#
#   num.vehicles_isna
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %%
df["num.vehicles_isna"].sum()
# Out:
# 56

# %% [markdown]
# ## Transformations

# %%
df = imputation.imput(custdata)

# %%
inspection.plot_features_density(df)

# %%
inspection.plot_features_density(df, plot_type="hist", )

# %%
skewed_feats = inspection.find_features_skewed(df, 20)
skewed_feats
# Out:
# array(['income'],
#       dtype='|S6')

# %%
log_df = transformation.log_transform(df[df.income > 0], skewed_feats)
inspection.plot_features_density(log_df)

# %%
## arcsinh - assume negative income is valid (e.g., debt)
arc_df = transformation.arcsinh_transform(df, skewed_feats)
inspection.plot_features_density(arc_df)

# %%
## signed_log - assume negative income is valid (e.g., debt)
slog_df = transformation.signed_log_transform(df, skewed_feats)
inspection.plot_features_density(slog_df)

# %%
inspection.plot_features_density(slog_df, plot_type="hist")

# %% [markdown]
# ## Pairwise plotting to find usefual single variable and correlation of variables

# %%
df = imputation.imput(custdata)
df = df[df.income > 0]
df = transformation.log_transform(df, ["income"])

# %%
print inspection.find_numerical_features(df)
print inspection.find_categorical_features(df)
# Out:
# ['custid' 'income' 'num.vehicles' 'age' 'log_income']
# ['sex' 'is.employed' 'marital.stat' 'health.ins' 'housing.type'
#  'recent.move' 'state.of.res' 'num.vehicles_isna']

# %%
inspection.plot_feature_pair(df, "age", "log_income")

# %%
inspection.plot_feature_pair(df, "marital.stat", "income")

# %%
inspection.plot_feature_pair(df, "age", "marital.stat")

# %%
inspection.plot_feature_pair(df, "marital.stat", "sex")

# %%
inspection.plot_feature_pair(df, "sex", "marital.stat")

# %%
inspection.plot_feature_pair(df, "num.vehicles", "health.ins", legend = True)

# %% [markdown]
# ## discretization of continous variables

# %%
print utility.is_discrete(df, "num.vehicles")
print utility.is_discrete(df, "custid")
# Out:
# False
# False

# %%
## default qcut
r = transformation.discretize_numerical(df, ["num.vehicles"], max_qcut = 100)
print np.unique(r["discrete_num.vehicles"])
r.loc[:, ["num.vehicles", "discrete_num.vehicles"]].head()
# Out:
# ['(1.717, 2]' '(2, 3]' '(3.364, 4]' '(4, 5]' '(5, 6]' '[0, 1]']
#    num.vehicles discrete_num.vehicles
# 0             2            (1.717, 2]
# 2             3                (2, 3]
# 3             0                [0, 1]
# 4             1                [0, 1]
# 5             1                [0, 1]

# %%
## equal bin size cut
r = transformation.discretize_numerical(df, ["income"], feat_bins = {"income": 10})
print np.unique(r["discrete_income"])
r.loc[:, ["income", "discrete_income"]].head()
# Out:
# ['(123024, 184521]' '(184521, 246018]' '(246018, 307515]'
#  '(307515, 369012]' '(369012, 430509]' '(430509, 492006]'
#  '(553503, 615000]' '(61527, 123024]' '[-584.97, 61527]']
#    income   discrete_income
# 0   11300  [-584.97, 61527]
# 2    4500  [-584.97, 61527]
# 3   20000  [-584.97, 61527]
# 4   12000  [-584.97, 61527]
# 5  180000  (123024, 184521]

# %%
## customized bins cut
r = transformation.discretize_numerical(df, ["age"], feat_bins = {"age": [-100, 0, 25, 30, 50, 60, 100, 150]})
print np.unique(r["discrete_age"])
r.loc[:, ["age", "discrete_age"]].head()
# Out:
# ['(0, 25]' '(100, 150]' '(25, 30]' '(30, 50]' '(50, 60]' '(60, 100]'
#  '[-100, 0]']
#    age discrete_age
# 0   49     (30, 50]
# 2   22      (0, 25]
# 3   22      (0, 25]
# 4   31     (30, 50]
# 5   40     (30, 50]

# %%
inspection.plot_feature_pair(r, "discrete_age", "health.ins")

# %% [markdown]
# ## Feature Engineering

# %%
t = pd.crosstab(r["health.ins"], r["discrete_age"], )
t
# Out:
# discrete_age  (0, 25]  (100, 150]  (25, 30]  (30, 50]  (50, 60]  (60, 100]  \
# health.ins
# False              13           0        21        57        17         11
# True               32           8        41       295       153        270
#
# discrete_age  [-100, 0]
# health.ins
# False                 0
# True                  3

# %%
a = t / t.sum(axis = 0)
a
# Out:
# discrete_age   (0, 25]  (100, 150]  (25, 30]  (30, 50]  (50, 60]  (60, 100]  \
# health.ins
# False         0.288889           0   0.33871  0.161932       0.1   0.039146
# True          0.711111           1   0.66129  0.838068       0.9   0.960854
#
# discrete_age  [-100, 0]
# health.ins
# False                 0
# True                  1

# %%
c = a.iloc[0, :]
c
# Out:
# discrete_age
# (0, 25]         0.288889
# (100, 150]      0.000000
# (25, 30]        0.338710
# (30, 50]        0.161932
# (50, 60]        0.100000
# (60, 100]       0.039146
# [-100, 0]       0.000000
# Name: False, dtype: float64

# %%
c.name = "HI"
c
# Out:
# discrete_age
# (0, 25]         0.288889
# (100, 150]      0.000000
# (25, 30]        0.338710
# (30, 50]        0.161932
# (50, 60]        0.100000
# (60, 100]       0.039146
# [-100, 0]       0.000000
# Name: HI, dtype: float64

# %%
#rr = pd.merge(r, pd.DataFrame(c).T, how = "left", on="discrete_age", )
rr = r.join(c, on = 'discrete_age', )

# %%
rr
# Out:
#       custid sex is.employed  income        marital.stat health.ins  \
# 0       2068   F     missing   11300             Married       True
# 2       2848   M        True    4500       Never Married      False
# 3       5641   M        True   20000       Never Married      False
# 4       6369   F        True   12000       Never Married       True
# 5       8322   F        True  180000       Never Married       True
# 6       8521   M        True  120000       Never Married       True
# 7      12195   M        True   40000             Married       True
# 8      14989   M     missing    9400             Married       True
# 9      15917   F        True   24000  Divorced/Separated       True
# 10     16551   F     missing    7000             Married       True
# 11     17134   M        True  220000             Married       True
# 12     17946   F        True   85000  Divorced/Separated       True
# 13     18487   F        True   89200  Divorced/Separated       True
# 14     20383   M        True  170000       Never Married       True
# 15     22295   M        True   14400             Married       True
# 16     25863   M     missing   41000  Divorced/Separated       True
# 17     26057   M        True   30000             Married       True
# 18     26355   M        True   80000       Never Married       True
# 19     27214   M     missing   18800             Married       True
# 20     27445   F        True   35000       Never Married       True
# 21     27761   M        True   24000       Never Married      False
# 22     27928   M        True   75000  Divorced/Separated       True
# 23     30768   M        True   80000             Married       True
# 24     31710   F        True  397000             Widowed       True
# 25     33651   F        True   45000       Never Married       True
# 26     33828   F        True   24900             Married       True
# 27     36825   M        True   17500             Married      False
# 28     37224   M        True   25800             Married       True
# 29     38827   F     missing    9700             Married       True
# 30     40132   M        True   22000             Married       True
# ..       ...  ..         ...     ...                 ...        ...
# 968  1379036   M       False   12000  Divorced/Separated      False
# 970  1380075   F     missing  248500             Widowed       True
# 971  1386080   F     missing   27000  Divorced/Separated       True
# 972  1386114   M        True   40000             Married       True
# 973  1386763   F        True   43600       Never Married       True
# 974  1388751   F       False   39000             Married       True
# 975  1390506   M        True   76000             Married       True
# 976  1391586   M     missing   22000             Married       True
# 977  1392011   F        True  402000             Married       True
# 978  1392648   M        True   70000             Married       True
# 979  1393413   M        True    9100       Never Married       True
# 980  1393715   F       False   25500       Never Married       True
# 981  1398054   M        True  125000             Married       True
# 983  1401383   F        True   50000             Married       True
# 984  1401938   F        True   32000  Divorced/Separated       True
# 985  1402550   M        True  200000             Married       True
# 986  1403515   M        True  382500             Married       True
# 987  1405584   F     missing    4000             Married       True
# 988  1407195   M        True   33000       Never Married      False
# 989  1407867   M        True  100300  Divorced/Separated       True
# 990  1407895   M        True   35000             Married       True
# 991  1407916   M        True   30000       Never Married       True
# 992  1408280   F        True   18000             Married       True
# 993  1408913   F     missing    1000             Married       True
# 994  1409249   M     missing   36200             Married       True
# 995  1411132   F       False   46000  Divorced/Separated       True
# 996  1411860   F     missing    5400             Widowed       True
# 997  1412161   M        True   38500             Married       True
# 998  1412971   M     missing   43400             Married       True
# 999  1414286   F       False   20900             Married      False
#
#                      housing.type recent.move  num.vehicles  age  \
# 0        Homeowner free and clear       False             2   49
# 2                          Rented        True             3   22
# 3           Occupied with no rent       False             0   22
# 4                          Rented        True             1   31
# 5    Homeowner with mortgage/loan       False             1   40
# 6        Homeowner free and clear        True             1   39
# 7                          Rented       False             3   48
# 8                          Rented       False             2   44
# 9        Homeowner free and clear       False             1   70
# 10   Homeowner with mortgage/loan       False             2   46
# 11       Homeowner free and clear        True             2   33
# 12                         Rented       False             1   51
# 13   Homeowner with mortgage/loan       False             1   63
# 14   Homeowner with mortgage/loan        True             1   35
# 15       Homeowner free and clear       False             3   54
# 16   Homeowner with mortgage/loan       False             1   70
# 17                        missing     missing             0   28
# 18   Homeowner with mortgage/loan       False             1   36
# 19       Homeowner free and clear       False             2   68
# 20                         Rented       False             2   53
# 21                         Rented       False             2   33
# 22   Homeowner with mortgage/loan       False             2   58
# 23   Homeowner with mortgage/loan       False             2   50
# 24   Homeowner with mortgage/loan       False             2   55
# 25   Homeowner with mortgage/loan       False             2   44
# 26   Homeowner with mortgage/loan       False             2   49
# 27                         Rented       False             2   35
# 28   Homeowner with mortgage/loan       False             2   48
# 29   Homeowner with mortgage/loan       False             2   72
# 30   Homeowner with mortgage/loan       False             3   66
# ..                            ...         ...           ...  ...
# 968         Occupied with no rent       False             2   61
# 970  Homeowner with mortgage/loan       False             1   81
# 971      Homeowner free and clear       False             1   65
# 972                        Rented       False             2   41
# 973                        Rented        True             1   29
# 974  Homeowner with mortgage/loan       False             3   45
# 975  Homeowner with mortgage/loan       False             2   33
# 976      Homeowner free and clear       False             4   64
# 977      Homeowner free and clear       False             1   50
# 978  Homeowner with mortgage/loan       False             5   60
# 979         Occupied with no rent       False             1   64
# 980                        Rented       False             1   48
# 981  Homeowner with mortgage/loan       False             3   34
# 983  Homeowner with mortgage/loan       False             2   57
# 984                        Rented       False             2   24
# 985  Homeowner with mortgage/loan        True             2   37
# 986  Homeowner with mortgage/loan       False             3   66
# 987  Homeowner with mortgage/loan       False             2   55
# 988  Homeowner with mortgage/loan        True             1   30
# 989  Homeowner with mortgage/loan       False             3   53
# 990  Homeowner with mortgage/loan       False             2   55
# 991  Homeowner with mortgage/loan       False             1   46
# 992  Homeowner with mortgage/loan       False             4   52
# 993                        Rented       False             0   60
# 994      Homeowner free and clear       False             5   73
# 995                        Rented        True             1   56
# 996                       missing     missing             0   89
# 997                        Rented        True             1   29
# 998      Homeowner free and clear       False             1   88
# 999                        Rented       False             2   36
#
#        state.of.res num.vehicles_isna  log_income discrete_age        HI
# 0          Michigan             False    9.332558     (30, 50]  0.161932
# 2           Georgia             False    8.411833      (0, 25]  0.288889
# 3        New Mexico             False    9.903488      (0, 25]  0.288889
# 4           Florida             False    9.392662     (30, 50]  0.161932
# 5          New York             False   12.100712     (30, 50]  0.161932
# 6             Idaho             False   11.695247     (30, 50]  0.161932
# 7          Michigan             False   10.596635     (30, 50]  0.161932
# 8          Illinois             False    9.148465     (30, 50]  0.161932
# 9    North Carolina             False   10.085809    (60, 100]  0.039146
# 10          Georgia             False    8.853665     (30, 50]  0.161932
# 11          Indiana             False   12.301383     (30, 50]  0.161932
# 12    New Hampshire             False   11.350407     (50, 60]  0.100000
# 13          Georgia             False   11.398636    (60, 100]  0.039146
# 14   South Carolina             False   12.043554     (30, 50]  0.161932
# 15     Pennsylvania             False    9.574983     (50, 60]  0.100000
# 16         Virginia             False   10.621327    (60, 100]  0.039146
# 17          Florida              True   10.308953     (25, 30]  0.338710
# 18       New Jersey             False   11.289782     (30, 50]  0.161932
# 19             Ohio             False    9.841612    (60, 100]  0.039146
# 20          Florida             False   10.463103     (50, 60]  0.100000
# 21         Illinois             False   10.085809     (30, 50]  0.161932
# 22         New York             False   11.225243     (50, 60]  0.100000
# 23       New Jersey             False   11.289782     (30, 50]  0.161932
# 24         Missouri             False   12.891692     (50, 60]  0.100000
# 25       California             False   10.714418     (30, 50]  0.161932
# 26        Wisconsin             False   10.122623     (30, 50]  0.161932
# 27     South Dakota             False    9.769956     (30, 50]  0.161932
# 28         Colorado             False   10.158130     (30, 50]  0.161932
# 29         Oklahoma             False    9.179881    (60, 100]  0.039146
# 30         Illinois             False    9.998798    (60, 100]  0.039146
# ..              ...               ...         ...          ...       ...
# 968        Michigan             False    9.392662    (60, 100]  0.039146
# 970      New Jersey             False   12.423198    (60, 100]  0.039146
# 971        New York             False   10.203592    (60, 100]  0.039146
# 972           Texas             False   10.596635     (30, 50]  0.161932
# 973       Tennessee             False   10.682812     (25, 30]  0.338710
# 974       Minnesota             False   10.571317     (30, 50]  0.161932
# 975        Illinois             False   11.238489     (30, 50]  0.161932
# 976            Ohio             False    9.998798    (60, 100]  0.039146
# 977        Virginia             False   12.904207     (30, 50]  0.161932
# 978        Michigan             False   11.156251     (50, 60]  0.100000
# 979      New Jersey             False    9.116030    (60, 100]  0.039146
# 980        Nebraska             False   10.146434     (30, 50]  0.161932
# 981        Maryland             False   11.736069     (30, 50]  0.161932
# 983        Michigan             False   10.819778     (50, 60]  0.100000
# 984      California             False   10.373491      (0, 25]  0.288889
# 985         Florida             False   12.206073     (30, 50]  0.161932
# 986         Indiana             False   12.854484    (60, 100]  0.039146
# 987      California             False    8.294050     (50, 60]  0.100000
# 988        Michigan             False   10.404263     (25, 30]  0.338710
# 989         Arizona             False   11.515921     (50, 60]  0.100000
# 990          Hawaii             False   10.463103     (50, 60]  0.100000
# 991       Louisiana             False   10.308953     (30, 50]  0.161932
# 992       Wisconsin             False    9.798127     (50, 60]  0.100000
# 993        Michigan             False    6.907755     (50, 60]  0.100000
# 994        New York             False   10.496814    (60, 100]  0.039146
# 995         Florida             False   10.736397     (50, 60]  0.100000
# 996    Pennsylvania              True    8.594154    (60, 100]  0.039146
# 997         Georgia             False   10.558414     (25, 30]  0.338710
# 998            Ohio             False   10.678215    (60, 100]  0.039146
# 999        New York             False    9.947504     (30, 50]  0.161932
#
# [921 rows x 15 columns]

# %%
categorical_feats = [f for f in inspection.find_categorical_features(r) if f != "health.ins"]
rr = feature.extract_cprobs_by_biclass(r, categorical_feats, "health.ins", )

# %%
rr.head().T
# Out:
#                                                         0              2  \
# custid                                               2068           2848
# sex                                                     F              M
# is.employed                                       missing           True
# income                                              11300           4500
# marital.stat                                      Married  Never Married
# health.ins                                           True          False
# housing.type                     Homeowner free and clear         Rented
# recent.move                                         False           True
# num.vehicles                                            2              3
# age                                                    49             22
# state.of.res                                     Michigan        Georgia
# num.vehicles_isna                                   False          False
# log_income                                       9.332558       8.411833
# discrete_age                                     (30, 50]        (0, 25]
# health.ins_on_sex                               0.1068702      0.1458333
# health.ins_on_is.employed                       0.0503876      0.1402337
# health.ins_on_marital.stat                     0.09052632      0.2634146
# health.ins_on_housing.type                     0.05882353      0.2145015
# health.ins_on_recent.move                       0.1208226      0.1785714
# health.ins_on_state.of.res                          0.125      0.1428571
# health.ins_on_num.vehicles_isna                 0.1280899      0.1280899
# health.ins_on_discrete_age                      0.1619318      0.2888889
#
#                                                      3              4  \
# custid                                            5641           6369
# sex                                                  M              F
# is.employed                                       True           True
# income                                           20000          12000
# marital.stat                             Never Married  Never Married
# health.ins                                       False           True
# housing.type                     Occupied with no rent         Rented
# recent.move                                      False           True
# num.vehicles                                         0              1
# age                                                 22             31
# state.of.res                                New Mexico        Florida
# num.vehicles_isna                                False          False
# log_income                                    9.903488       9.392662
# discrete_age                                   (0, 25]       (30, 50]
# health.ins_on_sex                            0.1458333      0.1068702
# health.ins_on_is.employed                    0.1402337      0.1402337
# health.ins_on_marital.stat                   0.2634146      0.2634146
# health.ins_on_housing.type                   0.2727273      0.2145015
# health.ins_on_recent.move                    0.1208226      0.1785714
# health.ins_on_state.of.res                         0.2     0.04444444
# health.ins_on_num.vehicles_isna              0.1280899      0.1280899
# health.ins_on_discrete_age                   0.2888889      0.1619318
#
#                                                             5
# custid                                                   8322
# sex                                                         F
# is.employed                                              True
# income                                                 180000
# marital.stat                                    Never Married
# health.ins                                               True
# housing.type                     Homeowner with mortgage/loan
# recent.move                                             False
# num.vehicles                                                1
# age                                                        40
# state.of.res                                         New York
# num.vehicles_isna                                       False
# log_income                                           12.10071
# discrete_age                                         (30, 50]
# health.ins_on_sex                                   0.1068702
# health.ins_on_is.employed                           0.1402337
# health.ins_on_marital.stat                          0.2634146
# health.ins_on_housing.type                         0.07848101
# health.ins_on_recent.move                           0.1208226
# health.ins_on_state.of.res                          0.1692308
# health.ins_on_num.vehicles_isna                     0.1280899
# health.ins_on_discrete_age                          0.1619318
